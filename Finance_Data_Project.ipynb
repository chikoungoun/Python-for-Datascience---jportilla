# %% [markdown]
# # Finance Data Project

# %% [markdown]
# Visualizing data analysis of stock prices using the Quandl API

# %% [markdown]
# **Notice : QUANDL/WIKI as of "March 2018" is no longer updated. Be sure to check the validity of your API before using them !**

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

# %%
import pandas_datareader.data as web
import datetime

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Importing Quandl api

# %%
import quandl
api_key = open('quandl_apikey.txt','r').read()
quandl.ApiConfig.api_key = api_key

# %% [markdown]
# ## Get the Data

# %% [markdown]
# We will get the data using pandas-reader from a list of banks, using their ticker symbols :
# - Bank of America - BAC
# - CitiGroup
# - Goldman Sachs
# - JPMorgan Chase
# - Morgan Stanley
# - Wells Fargo

# %% [markdown]
# The job would be to figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016. Each Bank should stand in a separate dataframe

# %%
#define  the time interval 
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

# %% [markdown]
# **Bank of America stocks**

# %%
BAC = quandl.get('WIKI/BAC',start_date=start,end_date=end)

# %%
BAC
# Out:
#              Open     High     Low  Close       Volume  Ex-Dividend  \
# Date
# 2006-01-03  46.92  47.1800  46.150  47.08   16296700.0         0.00
# 2006-01-04  47.00  47.2400  46.450  46.58   17757900.0         0.00
# 2006-01-05  46.58  46.8300  46.320  46.64   14970700.0         0.00
# 2006-01-06  46.80  46.9100  46.350  46.57   12599800.0         0.00
# 2006-01-09  46.72  46.9700  46.360  46.60   15619400.0         0.00
# 2006-01-10  46.40  46.5100  45.880  46.21   15634600.0         0.00
# 2006-01-11  46.06  46.2500  45.750  46.10   14742100.0         0.00
# 2006-01-12  46.22  46.2300  45.710  45.80   10546600.0         0.00
# 2006-01-13  45.83  46.0000  45.680  45.80   10791000.0         0.00
# 2006-01-17  45.40  45.5800  45.000  45.31   14605900.0         0.00
# 2006-01-18  45.32  45.6500  44.920  45.26   10867000.0         0.00
# 2006-01-19  45.88  45.8800  44.850  45.14   14584000.0         0.00
# 2006-01-20  45.00  45.1500  44.170  44.19   24950800.0         0.00
# ...

# %% [markdown]
# **Adding the other Banks**

# %%
#CitiGroup
C   = quandl.get('WIKI/C',start_date=start,end_date=end)
#Goldman Sachs
GS  = quandl.get('WIKI/GS',start_date=start,end_date=end)
#JPMorgan Chase
JPM = quandl.get('WIKI/JPM',start_date=start,end_date=end)
# Morgan Stanley
MS  = quandl.get('WIKI/MS',start_date=start,end_date=end)
#Wells Fargo
WFC = quandl.get('WIKI/WFC',start_date=start,end_date=end)

# %%
#Morgan Stanley data
MS.head()
# Out:
#              Open   High      Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 2006-01-03  57.17  58.49  56.7400  58.31  5377000.0          0.0          1.0
# 2006-01-04  58.70  59.28  58.3500  58.35  7977800.0          0.0          1.0
# 2006-01-05  58.55  58.59  58.0200  58.51  5778000.0          0.0          1.0
# 2006-01-06  58.77  58.85  58.0500  58.57  6889800.0          0.0          1.0
# 2006-01-09  58.63  59.29  58.6244  59.19  4144500.0          0.0          1.0
#
#             Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# Date
# 2006-01-03  39.548112  40.461240  39.250654   40.336722    5377000.0
# 2006-01-04  40.606510  41.007733  40.364393   40.364393    7977800.0
# 2006-01-05  40.502745  40.530416  40.136111   40.475075    5778000.0
# 2006-01-06  40.654933  40.710275  40.156864   40.516581    6889800.0
# 2006-01-09  40.558087  41.014650  40.554213   40.945474    4144500.0

# %% [markdown]
# #### Creating a list of the ticker symbols as stringd in alphabetical order

# %%
tickers = ['BAC','C','GS','JPM','MS','WFC']

# %% [markdown]
# #### Concatenate the bank dfs in a single one called 'bank stocks'.

# %%
bank_stocks = pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=tickers)

# %%
bank_stocks.head()
# Out:
#               BAC                                                           \
#              Open   High    Low  Close      Volume Ex-Dividend Split Ratio
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700.0         0.0         1.0
# 2006-01-04  47.00  47.24  46.45  46.58  17757900.0         0.0         1.0
# 2006-01-05  46.58  46.83  46.32  46.64  14970700.0         0.0         1.0
# 2006-01-06  46.80  46.91  46.35  46.57  12599800.0         0.0         1.0
# 2006-01-09  46.72  46.97  46.36  46.60  15619400.0         0.0         1.0
#
#                                                 ...        WFC         \
#             Adj. Open  Adj. High   Adj. Low     ...        Low  Close
# Date                                            ...
# 2006-01-03  37.126108  37.331837  36.516835     ...      62.39  63.80
# 2006-01-04  37.189409  37.379312  36.754214     ...      62.73  63.06
# 2006-01-05  36.857078  37.054894  36.651349     ...      62.62  62.99
# ...

# %% [markdown]
# #### Setting the column name levels

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker    BAC                                                           \
# Stock Info    Open   High    Low  Close      Volume Ex-Dividend Split Ratio
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700.0         0.0         1.0
# 2006-01-04   47.00  47.24  46.45  46.58  17757900.0         0.0         1.0
# 2006-01-05   46.58  46.83  46.32  46.64  14970700.0         0.0         1.0
# 2006-01-06   46.80  46.91  46.35  46.57  12599800.0         0.0         1.0
# 2006-01-09   46.72  46.97  46.36  46.60  15619400.0         0.0         1.0
#
# Bank Ticker                                      ...        WFC         \
# Stock Info   Adj. Open  Adj. High   Adj. Low     ...        Low  Close
# Date                                             ...
# 2006-01-03   37.126108  37.331837  36.516835     ...      62.39  63.80
# 2006-01-04   37.189409  37.379312  36.754214     ...      62.73  63.06
# 2006-01-05   36.857078  37.054894  36.651349     ...      62.62  62.99
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# Using 'Multi-Level Indexing' and '.xs'

# %% [markdown]
# #### What is the max Close Price for each bank's stock throughout the time period ?

# %% [markdown]
# Get the maw Close price of Bank of America :

# %%
bank_stocks['BAC']['Close'].max()
# Out:
# 54.899999999999999

# %% [markdown]
# Now generalize it on all the other stocks

# %%
for tick in tickers:
    print(tick+' : ',bank_stocks[tick]['Close'].max())
# Out:
# BAC :  54.9
# C :  60.34
# GS :  247.92
# JPM :  70.08
# MS :  89.3
# WFC :  73.0

# %% [markdown]
# **<u>Method 2</u> : ** Using Cross section ** .xs() **

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.90
# C       60.34
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     73.00
# dtype: float64

# %% [markdown]
# #### Creating a new DF called 'returns' containing the returns for each bank's stock.

# %% [markdown]
# **Returns Formula : **
# <br/>
# <h2>$r_t = \frac{p_t \thinspace - \thinspace p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1 $</h2>

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+' Return'] = bank_stocks[tick]['Close'].pct_change()

# %%
returns.head(10)
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158
# 2006-01-10   -0.008369  0.003100   0.012578    0.001475   0.000507   -0.000789
# 2006-01-11   -0.002380  0.009065  -0.000454   -0.000737   0.005910    0.005213
# 2006-01-12   -0.006508  0.001021   0.002122   -0.018428  -0.001679   -0.011630
# 2006-01-13    0.000000 -0.002244   0.007637   -0.000751  -0.001513    0.005724
# 2006-01-17   -0.010699 -0.010016  -0.005028   -0.005261  -0.009599   -0.010277

# %% [markdown]
# #### Creating a pairplot using seaborn of the 'returns' Dataframe

# %%
import seaborn as sns

# %%
sns.pairplot(data=returns[1:])#To avoid the Nan data

# %% [markdown]
# #### Using the returns Dataframe to figure out the best and worst single day returns

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %% [markdown]
# Return the date of the minimum return (worst):

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2006-08-14
# dtype: datetime64[ns]

# %% [markdown]
# Return the date of the maximum return (best):

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2011-05-09
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# #### Caluclating the standard deviation of stocks :
# - Large Std : stocks going up and down a lot => Higher Risk
# - Small Std : pprices are pretty steady => Lower Risk

# %%
returns.std()
# Out:
# BAC Return    0.036628
# C Return      0.179066
# GS Return     0.025358
# JPM Return    0.027651
# MS Return     0.037820
# WFC Return    0.031838
# dtype: float64

# %% [markdown]
# - We can notice that CitiGroup is the riskiest

# %% [markdown]
# #### Standard deviations of 2015

# %%
returns.ix['2015 01 01' : '2015 12 31'].std()
# Out:
# c:\users\marwane\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# - Far from the crash of citigroup, all the stocks are pretty much similar in risks

# %% [markdown]
# #### Creating a distplot with seaborn of the 2015 returns for Morgan Stanley

# %%
sns.distplot(returns.ix['2015 01 01' : '2015 12 31']['MS Return'],color='green',bins=50)

# %% [markdown]
# #### Creating a distplot of the 2008 returns for CitiGroup

# %%
sns.distplot(returns.ix['2008 01 01' : '2008 12 31']['C Return'],color='red',bins=50)

# %% [markdown]
# ## More Visualization

# %% [markdown]
# #### Creating a line plot of Close price for each bank for the entire index of time

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot(figsize=(12,4))

# %% [markdown]
# **Method 2 : ** with "for loop"

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick, figsize=(12,4))
plt.legend()

# %% [markdown]
# ## Moving Averages

# %% [markdown]
# moving averages of the stocks in the year 2008.

# %% [markdown]
# #### Plotting the rolling 30 day average of the Close Price for BAC in 2008

# %%
BAC['Close'].ix['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 day moving average')
BAC['Close'].ix['2008-01-01':'2009-01-01'].plot(label='BAC Close',figsize=(12,4))
plt.legend()
